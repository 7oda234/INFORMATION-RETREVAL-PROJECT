# %% [markdown]
# **Importing the library we will use:**

# %%
import pandas as pd
df=pd.read_csv("/content/mobile_sales_data-DESKTOP-M7R9051.csv")

# %% [markdown]
# **To get the first # of rows:**

# %%
df.head(3)
# Out:
#         Product     Brand Product Code  \
# 0  Mobile Phone  Motorola     88EB4558
# 1        Laptop      Oppo     416DFEEB
# 2  Mobile Phone   Samsung     9F975B08
#
#                                Product Specification   Price  Inward Date  \
# 0  Site candidate activity company there bit insi...   78570        45140
# 1            Beat put care fight affect address his.   44613        45202
# 2           Energy special low seven place audience.  159826        45735
#
#    Dispatch Date  Quantity Sold  Customer Name Customer Location   Region  \
# 0          45141              6   William Hess      South Kelsey  Central
# 1          45205              1    Larry Smith        North Lisa    South
# 2          45736              5  Leah Copeland        South Todd  Central
#
#   Core Specification Processor Specification   RAM    ROM    SSD
# 0                NaN        Snapdragon 7 Gen  12GB  128GB    NaN
# 1            Ryzen 5                 Ryzen 5   8GB  512GB  256GB
# ...

# %% [markdown]
# **To get the last # of rows:**

# %%
df.tail(3)
# Out:
#             Product    Brand Product Code  \
# 49997        Laptop  Toshiba     CAD89A93
# 49998  Mobile Phone   Lenovo     78566C17
# 49999        Laptop     Asus     9C3FC57C
#
#                                    Product Specification   Price  Inward Date  \
# 49997  Test floor tax together out adult discover own...   66502        45307
# 49998               Away also magazine receive such lay.  158883        45061
# 49999      Role ahead common listen idea few blood half.   86483        45167
#
#        Dispatch Date  Quantity Sold      Customer Name      Customer Location  \
# 49997          45356              6      Joseph Martin               Huntfurt
# 49998          45071              2  Gabrielle Barnett              Heidiberg
# 49999          45225              7     Robert Sampson  West Elizabethchester
#
#       Region Core Specification Processor Specification   RAM    ROM    SSD
# 49997  North                 i5                      i5   4GB   64GB    2TB
# ...

# %% [markdown]
# **To get all info about the dataset:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product                  50000 non-null  object
#  1   Brand                    50000 non-null  object
#  2   Product Code             50000 non-null  object
#  3   Product Specification    50000 non-null  object
#  4   Price                    50000 non-null  int64
#  5   Inward Date              50000 non-null  int64
#  6   Dispatch Date            50000 non-null  int64
#  7   Quantity Sold            50000 non-null  int64
#  8   Customer Name            50000 non-null  object
#  9   Customer Location        50000 non-null  object
#  10  Region                   50000 non-null  object
#  11  Core Specification       25017 non-null  object
#  12  Processor Specification  50000 non-null  object
#  13  RAM                      50000 non-null  object
# ...

# %% [markdown]
# **To get some summary statistics for the dataset:**

# %%
df.describe()
# Out:
#                Price   Inward Date  Dispatch Date  Quantity Sold
# count   50000.000000  50000.000000   50000.000000    50000.00000
# mean   102641.407080  45370.737480   45401.329520        5.51378
# std     56363.550361    210.964495     211.611159        2.88101
# min      5008.000000  45006.000000   45008.000000        1.00000
# 25%     53487.000000  45189.000000   45219.000000        3.00000
# 50%    103072.000000  45370.000000   45400.000000        6.00000
# 75%    151396.250000  45553.000000   45584.000000        8.00000
# max    199999.000000  45736.000000   45795.000000       10.00000

# %% [markdown]
# **To get the total number of columns and rows:**

# %%
df.shape
# Out:
# (50000, 16)

# %% [markdown]
# **To mention all columns found in the dataset:**

# %%
df.columns
# Out:
# Index(['Product', 'Brand', 'Product Code', 'Product Specification', 'Price',
#        'Inward Date', 'Dispatch Date', 'Quantity Sold', 'Customer Name',
#        'Customer Location', 'Region', 'Core Specification',
#        'Processor Specification', 'RAM', 'ROM', 'SSD'],
#       dtype='object')

# %% [markdown]
# **To get the lenght of the dataset (Number of Rows)**

# %%
len(df)
# Out:
# 50000

# %% [markdown]
# **To know if there is null values or not:**

# %%
df.isnull()
# Out:
#        Product  Brand  Product Code  Product Specification  Price  \
# 0        False  False         False                  False  False
# 1        False  False         False                  False  False
# 2        False  False         False                  False  False
# 3        False  False         False                  False  False
# 4        False  False         False                  False  False
# ...        ...    ...           ...                    ...    ...
# 49995    False  False         False                  False  False
# 49996    False  False         False                  False  False
# 49997    False  False         False                  False  False
# 49998    False  False         False                  False  False
# 49999    False  False         False                  False  False
#
#        Inward Date  Dispatch Date  Quantity Sold  Customer Name  \
# 0            False          False          False          False
# ...

# %% [markdown]
# **To know the number of null fields:**

# %%
df.isnull().sum()
# Out:
# Product                        0
# Brand                          0
# Product Code                   0
# Product Specification          0
# Price                          0
# Inward Date                    0
# Dispatch Date                  0
# Quantity Sold                  0
# Customer Name                  0
# Customer Location              0
# Region                         0
# Core Specification         24983
# Processor Specification        0
# RAM                            0
# ROM                            0
# SSD                        24983
# dtype: int64

# %% [markdown]
# **To group data by by a specific thing:**

# %%
df.groupby("Brand")["Quantity Sold"].sum()
# Out:
# Brand
# Acer         13854
# Apple        14197
# Asus         12999
# Dell         13419
# Google       14412
# HP           13600
# Huawei       13805
# Lenovo       13723
# Microsoft    13586
# Motorola     13888
# Nokia        14239
# OnePlus      13880
# Oppo         13389
# Realme       13212
# Redmi        13948
# Samsung      14033
# Sony         14043
# Toshiba      13996
# Vivo         13761
# iQOO         13705
# Name: Quantity Sold, dtype: int64

# %% [markdown]
# **To sort values by a specific metric:**

# %%
df.sort_values("Brand")
# Out:
#             Product Brand Product Code  \
# 28509        Laptop  Acer     2583D3F0
# 42457        Laptop  Acer     5523B06C
# 46590        Laptop  Acer     7567ABC8
# 46588        Laptop  Acer     0C6FA0D6
# 20591        Laptop  Acer     CD81658D
# ...             ...   ...          ...
# 19634        Laptop  iQOO     32B996C3
# 34799        Laptop  iQOO     F041E139
# 9344         Laptop  iQOO     F6BAF3BF
# 4969   Mobile Phone  iQOO     CC7562FC
# 19733        Laptop  iQOO     F5D5EC98
#
#                                    Product Specification   Price  Inward Date  \
# 28509  Article yourself affect yet administration not...  132105        45411
# 42457  Catch remember southern heart model tend profe...  128985        45547
# 46590     Response must someone outside billion develop.   14605        45671
# 46588  Owner president party change old assume simila...  178248        45178
# 20591  Big have partner same mission manage oil evide...   92592        45052
# ...

# %% [markdown]
# To get all rows that has a specific data:

# %%
df[df["Brand"]== "Apple"]
# Out:
#             Product  Brand Product Code  \
# 7            Laptop  Apple     D58FF785
# 8            Laptop  Apple     4FC302CF
# 10     Mobile Phone  Apple     F54013D6
# 92     Mobile Phone  Apple     0C376DC0
# 94           Laptop  Apple     2E475456
# ...             ...    ...          ...
# 49893        Laptop  Apple     E92A136C
# 49928  Mobile Phone  Apple     EDF904DD
# 49956        Laptop  Apple     361A5C77
# 49979  Mobile Phone  Apple     EA3CF7E0
# 49992        Laptop  Apple     D0D615DC
#
#                                    Product Specification   Price  Inward Date  \
# 7      Reality sea weight thing newspaper good next g...   15041        45228
# 8      Owner necessary total determine view stock chu...  186647        45196
# 10                          To say system loss near him.   51251        45019
# 92      Worker pretty lead agent there performance hold.   66597        45617
# 94     Vote chance toward meeting manager hot music s...  150198        45082
# ...
